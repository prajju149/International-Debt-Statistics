# %% [markdown]
# # Part 2: 2 Feature Engineering

# %%
import pandas as pd

df = pd.read_csv("cleaned_data.csv")

# Create new features
df['Debt per Capita'] = df['Total Debt'] / df['Population']
df['Debt to GDP (%)'] = (df['Total Debt'] / df['GDP']) * 100

df.to_csv("engineered_data.csv", index=False)
