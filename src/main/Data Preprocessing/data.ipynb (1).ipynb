# %% [markdown]
# # Part 3: 3 Data Integrity Consistency

# %%
import pandas as pd

df = pd.read_csv("engineered_data.csv")

# Remove duplicates
df.drop_duplicates(inplace=True)

# Remove rows with negative values
df = df[df['Total Debt'] >= 0]

df.to_csv("consistent_data.csv", index=False)
